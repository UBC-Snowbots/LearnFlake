# %%
# Importing libraries

import gymnasium as gym
import robosuite as robs
import robosuite.wrappers.gym_wrapper as GymWrapper
from gym_wrapper import RobosuiteGymWrapper
from stable_baselines3 import PPO

# %%
env = RobosuiteGymWrapper("Lift", robots="Panda", has_renderer=True, use_camera_obs=False, reward_shaping=True)

model = PPO.load("/home/pranav/Documents/LearnFlake/src/rl_autonomy/rl_agent/ppo-lift-model-train1.zip", env = env) # Loads trained model

model = PPO("MlpPolicy", env, verbose=1)

# Making the environment, loading trained model and declaring policy
# Out:
# [robosuite INFO] Loading controller configuration from: /home/pranav/Documents/LearnFlake/src/external_pkgs/RoboSuite/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /home/pranav/Documents/LearnFlake/src/external_pkgs/RoboSuite/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train the model
model.learn(total_timesteps=1000)
# Out:
# [robosuite INFO] Loading controller configuration from: /home/pranav/Documents/LearnFlake/src/external_pkgs/RoboSuite/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# /home/pranav/.local/lib/python3.10/site-packages/glfw/__init__.py:917: GLFWError: (65548) b'Wayland: The platform does not provide the window position'
#   warnings.warn(message, GLFWError)
# [robosuite INFO] Loading controller configuration from: /home/pranav/Documents/LearnFlake/src/external_pkgs/RoboSuite/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /home/pranav/Documents/LearnFlake/src/external_pkgs/RoboSuite/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.23     |
# ...

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, render=True)

# Testing stage

model.save("ppo_lift_model")
# Out:
# /home/pranav/anaconda3/envs/robosuite/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [robosuite INFO] Loading controller configuration from: /home/pranav/Documents/LearnFlake/src/external_pkgs/RoboSuite/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# /home/pranav/anaconda3/envs/robosuite/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# ...
