# %% [markdown]
# ## Testing the STL Rendering of the Keyboard

# %%
import os
import sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))

from keyboard_env import KeyboardEnv

env = KeyboardEnv(render=True, use_mesh=True, randomize_keyboard_pos=True)

for ep in range(5):
    env.reset()
    for _ in range(200):
        env.step([0]*7)

env.close()
# Out:
# [robosuite INFO] Loading controller configuration from: /home/kingcammy/LearnFlake/src/rl_autonomy/../external_pkgs/RoboSuite/robosuite/controllers/config/robots/default_rover2026.json (composite_controller_factory.py:121)
